# %%
import numpy as np

# %%
a = np.array([[1,2,3],[4,5,6]])

# %%
a[0,1] #first array second element
# Out:
# 2

# %%
#a[array number, index number]

# %%
a.ndim #ndim = return dimension of array
# Out:
# 2

# %%
#when we create an array with multidimension all of the arrays must be same length.
#multidimension arrayler oluşturduğumuzda tüm arrayler aynı sayıda eleman içermelidir. Aksi takdirde dimension doğru çalışmaz.
#example => c = np.array([[8,9,7],[2,3,4,5]]) if we create an array like that, it can't understand that there are 2 dimension.
#behaves like one dimensional array

# %%
b = np.array([[[1,2,3],[4,5,6],[9,9,8]],[[-1,-2,-3],[-4,-5,-6],[-9,-9,-8]]])

# %%
#np.array(square brackets of array <= [ [numbers],[numbers] ] => square brackets of array)
#np.array(array'e ait köşeli parantez <= [ [[numbers],[numbers]], [[numbers],[numbers]] ] => array'e ait köşeli parantez)

# %%
b.ndim
# Out:
# 3

# %%
b.shape
# Out:
# (2, 3, 3)

# %%
#2 means how many 2 dimensional array in b
#each 2 dimensional array how many 1 dimensional array in b => 3
#each 1 dimensional array how many elements here => 3

# %%
print(b.shape[0], b.shape[1], b.shape[2])
# Out:
# 2 3 3

# %%
#shape[0] = total numbers of 2 dimensional array
#shape[1] = each 2D array how many 1D arrays in there
#shape[2] = each 1D array how many elements in there

# %%
b[1,0,2] #third element of the first array which contains second array
# Out:
# -3

# %%
b[0,2,2]
# Out:
# 8

# %%
S = np.array([9])

# %%
S.ndim
# Out:
# 1

# %%
S2 = np.array(5)

# %%
S2.ndim
# Out:
# 0

# %%
b.size #total number of elements
# Out:
# 18

# %%
b.nbytes #total bytes taking inside the memory
# Out:
# 144
