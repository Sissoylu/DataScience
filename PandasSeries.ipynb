# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 1.1.5

# %%
data = pd.Series([0.20,0.40,0.60,0.80],index=['a','b','c','d']) #that means 0.20 = a, 0.40 = b and so on
#pd.Series([values],index=[indexes])

# %%
data
# Out:
# a    0.2
# b    0.4
# c    0.6
# d    0.8
# dtype: float64

# %%
data.values
# Out:
# array([0.2, 0.4, 0.6, 0.8])

# %%
data.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
type(data.values)
# Out:
# numpy.ndarray

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
data['a'] #we can reach the values using defined index
# Out:
# 0.2

# %%
data['d']
# Out:
# 0.8

# %%
data['a':'c'] #a to c
#final index is included (c)
# Out:
# a    0.2
# b    0.4
# c    0.6
# dtype: float64

# %%
grades_dict = {'A':4, 'B':3.5, 'C':3, 'D':2.5}

# %%
grades = pd.Series(grades_dict)

# %%
grades
# Out:
# A    4.0
# B    3.5
# C    3.0
# D    2.5
# dtype: float64

# %%
grades.values
# Out:
# array([4. , 3.5, 3. , 2.5])

# %%
puans_dict = {'A':90, 'B':80, 'C':70, 'D':60}

# %%
puan = pd.Series(puans_dict)

# %%
puan
# Out:
# A    90
# B    80
# C    70
# D    60
# dtype: int64

# %%
puan['A']
# Out:
# 90

# %%
puan['A':'D']
# Out:
# A    90
# B    80
# C    70
# D    60
# dtype: int64

# %%
puan[0:3] #3. index not included, sayı kullanarak yapıldığında son index dahil edilmez.
# Out:
# A    90
# B    80
# C    70
# dtype: int64
