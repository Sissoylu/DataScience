# %%
import numpy as np

# %%
a = np.array([1,2,3,4,5]) #no differences whether if it is array or tuple
# also we can define the datatype while creating the np array 
# a = np.array([1,2,3,4,5],dtype = 'i') => i is integer, f is float

# %%
b = np.array((1,6,3,4,9), dtype = 'f')

# %%
print(a)
# Out:
# [1 2 3 4 5]

# %%
print(b)
# Out:
# [1 6 3 4 9]

# %%
type(a)
# Out:
# numpy.ndarray

# %%
type(b)
# Out:
# numpy.ndarray

# %%
a.dtype #a'nın datatype ını bize döndürecek
# Out:
# dtype('int64')

# %%
b.dtype
# Out:
# dtype('float32')
