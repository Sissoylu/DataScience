# %%
import pandas as pd

# %%
grades_dict = {'A':4, 'B':3.5, 'C':3, 'D':2.5}

# %%
grades = pd.Series(grades_dict)

# %%
puans_dict = {'A':90, 'B':80, 'C':70, 'D':60}

# %%
puan = pd.Series(puans_dict)

# %%
dFrame = pd.DataFrame({'Marks':puan, 'Grades':grades})

# %%
dFrame
# Out:
#    Marks  Grades
# A     90     4.0
# B     80     3.5
# C     70     3.0
# D     60     2.5

# %%
#Transpoz
dFrame.T
# Out:
#            A     B     C     D
# Marks   90.0  80.0  70.0  60.0
# Grades   4.0   3.5   3.0   2.5

# %%
dFrame.values
# Out:
# array([[90. ,  4. ],
#        [80. ,  3.5],
#        [70. ,  3. ],
#        [60. ,  2.5]])

# %%
dFrame.values[2,0]
# Out:
# 70.0

# %%
dFrame.columns
# Out:
# Index(['Marks', 'Grades'], dtype='object')

# %%
dFrame
# Out:
#    Marks  Grades
# A     90     4.0
# B     80     3.5
# C     70     3.0
# D     60     2.5

# %%
#add another column
dFrame['ScMarks'] = 100*(dFrame['Marks'])/95

# %%
dFrame
# Out:
#    Marks  Grades    ScMarks
# A     90     4.0  94.736842
# B     80     3.5  84.210526
# C     70     3.0  73.684211
# D     60     2.5  63.157895

# %%
del dFrame['ScMarks']

# %%
dFrame
# Out:
#    Marks  Grades
# A     90     4.0
# B     80     3.5
# C     70     3.0
# D     60     2.5

# %%
scale = dFrame[dFrame['Marks']>70]

# %%
scale
# Out:
#    Marks  Grades
# A     90     4.0
# B     80     3.5

# %%
dFrame2 = pd.DataFrame([{'a':5, 'b':3}, {'b':-1, 'c':6}])

# %%
dFrame2 #Nan = none
# Out:
#      a  b    c
# 0  5.0  3  NaN
# 1  NaN -1  6.0

# %%
dFrame2.fillna(0) #missing values filled with 0
# Out:
#      a  b    c
# 0  5.0  3  0.0
# 1  0.0 -1  6.0
